# %%
#essai1
name=input("inter your name please")
print(name)
# Out:
# inter your name pleaseMelissa Gamar
# Melissa Gamar

# %%
#question1
prenom=input("veuillez saisir votre prenom:")
nom=input("veuillez saisir votre nom:")
print(nom,prenom)
# Out:
# veuillez saisir votre prenom:Melissa
# veuillez saisir votre nom:Gamar
# Gamar Melissa

# %%
#question2
n=input("n:") #la saisie en input est considerer comme STR
nn=n+n
nnn=n+n+n
s=int(n)+int(nn)+int(nnn)
print("n:",n,"nn:",nn,"nnn:",nnn)
print("resultat:",s)
# Out:
# n:5
# n: 5 nn: 55 nnn: 555
# resultat: 615

# %%
#question3
x=input("x:")
x=int(x)
n=x%2

if n==0:
    print(x,"ce nombre est pair")
else:
    print(x,"ce nombre est impair")
# Out:
# x:3
# 3 ce nombre est impair

# %%
#essaidequestion4
for i in range(2000,3201,1):
 r=i%7   
 if r==0:
    print(i,"multiple de 7")
 n=i%5
 if n==0:
    print(i,"multiple de 5")
 if n==0 and r==0:
    print(i,"myltiple de 5 et de 7")
# Out:
# 2000 multiple de 5
# 2002 multiple de 7
# 2005 multiple de 5
# 2009 multiple de 7
# 2010 multiple de 5
# 2015 multiple de 5
# 2016 multiple de 7
# 2020 multiple de 5
# 2023 multiple de 7
# 2025 multiple de 5
# 2030 multiple de 7
# 2030 multiple de 5
# 2030 myltiple de 5 et de 7
# 2035 multiple de 5
# 2037 multiple de 7
# 2040 multiple de 5
# 2044 multiple de 7
# 2045 multiple de 5
# 2050 multiple de 5
# 2051 multiple de 7
# 2055 multiple de 5
# 2058 multiple de 7
# 2060 multiple de 5
# 2065 multiple de 7
# 2065 multiple de 5
# 2065 myltiple de 5 et de 7
# 2070 multiple de 5
# 2072 multiple de 7
# 2075 multiple de 5
# 2079 multiple de 7
# 2080 multiple de 5
# 2085 multiple de 5
# 2086 multiple de 7
# 2090 multiple de 5
# 2093 multiple de 7
# 2095 multiple de 5
# 2100 multiple de 7
# 2100 multiple de 5
# 2100 myltiple de 5 et de 7
# 2105 multiple de 5
# 2107 multiple de 7
# 2110 multiple de 5
# 2114 multiple de 7
# 2115 multiple de 5
# 2120 multiple de 5
# 2121 multiple de 7
# ...

# %%
#question4
for i in range(2000,3200,1):
 r=i%7   
 n=i%5
 if n!=0 and r==0:
    print(i , end = " ")
# Out:
# 2002 2009 2016 2023 2037 2044 2051 2058 2072 2079 2086 2093 2107 2114 2121 2128 2142 2149 2156 2163 2177 2184 2191 2198 2212 2219 2226 2233 2247 2254 2261 2268 2282 2289 2296 2303 2317 2324 2331 2338 2352 2359 2366 2373 2387 2394 2401 2408 2422 2429 2436 2443 2457 2464 2471 2478 2492 2499 2506 2513 2527 2534 2541 2548 2562 2569 2576 2583 2597 2604 2611 2618 2632 2639 2646 2653 2667 2674 2681 2688 2702 2709 2716 2723 2737 2744 2751 2758 2772 2779 2786 2793 2807 2814 2821 2828 2842 2849 2856 2863 2877 2884 2891 2898 2912 2919 2926 2933 2947 2954 2961 2968 2982 2989 2996 3003 3017 3024 3031 3038 3052 3059 3066 3073 3087 3094 3101 3108 3122 3129 3136 3143 3157 3164 3171 3178 3192 3199

# %%
#question5
n=input("n:")
n=int(n)
p=1
i=1
while i<n:
 i=i+1
 p=p*i
print(p)
# Out:
# n:8
# 40320

# %%
#question6
str="hello team"
print(str[0:10:2])
len(str)
# Out:
# hlota
# 10

# %%
#question7
x=input("le prix:")
x=int(x)

if x>=500:
    print("remise de 50%")
elif x>=200:
    print("remise de 30%")
else:
    print("remise de 10%")
# Out:
# le prix:100
# remise de 10%
